# %%
import pandas as pd
import numpy as np


# Load Data



train = pd.read_csv("../data/train.csv")
test = pd.read_csv("../data/test.csv")
features = pd.read_csv("../data/features.csv")
stores = pd.read_csv("../data/stores.csv")

# Merge Data


data = train.merge(features, on=["Store", "Date", "IsHoliday"], how="left")
data = data.merge(stores, on="Store", how="left")

# Fill Missing Values


markdown_cols = ["MarkDown1", "MarkDown2", "MarkDown3", "MarkDown4", "MarkDown5"]

data[markdown_cols] = data[markdown_cols].fillna(0)


    # Date Feature 

data["Date"] = pd.to_datetime(data["Date"])
data["Year"] = data["Date"].dt.year
data["Month"] = data["Date"].dt.month
data["Day"] = data["Date"].dt.day

#  column remove
data.drop("Date", axis=1, inplace=True)

print("Data loaded successfully!")

print(data.shape)

data.head()



data.to_csv("../data/processed_data.csv", index=False)
# Out:
# Data loaded successfully!
# (421570, 18)

# %%
data.head()
# Out:
#         Store  Dept  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 421565     45    98        508.37      False        64.88       3.997
# 421566     45    98        628.10      False        64.89       3.985
# 421567     45    98       1061.02      False        54.47       4.000
# 421568     45    98        760.01      False        56.47       3.969
# 421569     45    98       1076.80      False        58.85       3.882
#
#         MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 421565    4556.61      20.64       1.50    1601.01    3288.25  192.013558
# 421566    5046.74       0.00      18.82    2253.43    2340.01  192.170412
# 421567    1956.28       0.00       7.89     599.32    3990.54  192.327265
# 421568    2004.02       0.00       3.18     437.73    1537.49  192.330854
# 421569    4018.91      58.08     100.00     211.94     858.33  192.308899
#
#         Unemployment Type    Size  Year  Month  Day
# 421565         8.684    B  118221  2012      9   28
# 421566         8.667    B  118221  2012     10    5
# 421567         8.667    B  118221  2012     10   12
# 421568         8.667    B  118221  2012     10   19
# 421569         8.667    B  118221  2012     10   26

# %%
data.tail()
# Out:
#         Store  Dept  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 421565     45    98        508.37      False        64.88       3.997
# 421566     45    98        628.10      False        64.89       3.985
# 421567     45    98       1061.02      False        54.47       4.000
# 421568     45    98        760.01      False        56.47       3.969
# 421569     45    98       1076.80      False        58.85       3.882
#
#         MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 421565    4556.61      20.64       1.50    1601.01    3288.25  192.013558
# 421566    5046.74       0.00      18.82    2253.43    2340.01  192.170412
# 421567    1956.28       0.00       7.89     599.32    3990.54  192.327265
# 421568    2004.02       0.00       3.18     437.73    1537.49  192.330854
# 421569    4018.91      58.08     100.00     211.94     858.33  192.308899
#
#         Unemployment Type    Size  Year  Month  Day
# 421565         8.684    B  118221  2012      9   28
# 421566         8.667    B  118221  2012     10    5
# 421567         8.667    B  118221  2012     10   12
# 421568         8.667    B  118221  2012     10   19
# 421569         8.667    B  118221  2012     10   26
