# %%
import pandas as pd
import numpy as np
import joblib


from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

print("loading..")

l_model = joblib.load("../models/linear_regression.pkl")
best_rf = joblib.load("../models/best_random_forest.pkl")
best_xgb = joblib.load("../models/best_xgboost.pkl")

print("run successfully")
# Out:
# loading..
# run successfully

# %%
l_pred = l_model.predict(X_test)

rf_pred = best_rf.predict(X_test)

xgb_pred = best_xgb.predict(X_test)


comparison = pd.DataFrame({
    "Model": [
        "Linear Regression",
        "Random Forest",
        "XGBoost"] ,
        
    "MAE"  : [
        mean_absolute_error(y_test, l_pred),
        mean_absolute_error(y_test, rf_pred),
        mean_absolute_error(y_test, xgb_pred)
    ],
    "MSE": [
        mean_squared_error(y_test, l_pred),
        mean_squared_error(y_test, rf_pred),
        mean_squared_error(y_test, xgb_pred)
    ],

    "R2 Score": [
        r2_score(y_test, l_pred),
        r2_score(y_test, rf_pred),
        r2_score(y_test, xgb_pred)
    ]
    })

print(comparison)
# Out:
#                Model           MAE           MSE  R2 Score
# 0  Linear Regression  14377.532705  4.607822e+08  0.116380
# 1      Random Forest   9253.410135  2.259857e+08  0.566638
# 2            XGBoost   4590.568843  5.808321e+07  0.888617
